# %%
import pandas as pd
d1 = pd.read_csv('result.csv',encoding='gbk')
d1
# Out:
#                   抓取时间                搜索词  \
# 0     2019/11/16 11:34  江苏生日送花送几朵鲜花礼品网可以吗
# 1     2019/11/16 11:34  江苏生日送花送几朵鲜花礼品网可以吗
# 2     2019/11/16 11:34  江苏生日送花送几朵鲜花礼品网可以吗
# 3     2019/11/16 11:34  江苏生日送花送几朵鲜花礼品网可以吗
# 4     2019/11/16 11:34  江苏生日送花送几朵鲜花礼品网可以吗
# ...                ...                ...
# 1114  2019/11/16 11:37         江苏姑苏区鲜花礼品网
# 1115  2019/11/16 11:37         江苏姑苏区鲜花礼品网
# 1116  2019/11/16 11:37         江苏姑苏区鲜花礼品网
# 1117  2019/11/16 11:37         江苏姑苏区鲜花礼品网
# 1118  2019/11/16 11:37         江苏姑苏区鲜花礼品网
#
#                                        创意标题              标题飘红  \
# 0                                       NaN               NaN
# 1                                       NaN               NaN
# 2     中国\n鲜花网礼品网\n_花礼网Hua.com 1-3小时\n送花\n服务               NaN
# 3                                       NaN               NaN
# 4              江苏\n送鲜花\n实体花店 爱上\n鲜花\n送花\n上门               NaN
# ...                                     ...               ...
# ...

# %%
d2 = pd.read_csv('result_jiangsu_xiawu.csv',encoding='gbk')

# %%
d3 = pd.read_csv('result_jiangsu_wanshang.csv',encoding='gbk')
d4 = pd.read_csv('result_jiangsu_zaoshang.csv',encoding='gbk')

# %%
result_list = [d2,d3,d4,d1]
data = pd.concat(result_list,ignore_index=True)

# %%
data
# Out:
#                   抓取时间         搜索词                                  创意标题  \
# 0     2019/11/15 16:52    江苏鲜花全国速递          江苏鲜花价格_江苏鲜花最新报价_江苏鲜花多少钱-苏宁易购
# 1     2019/11/15 16:52    江苏鲜花全国速递                   江苏鲜花快递服务_江苏鲜花快递服务电话
# 2     2019/11/15 16:52    江苏鲜花全国速递                  江苏同城鲜花快递_江苏同城鲜花速递手机版
# 3     2019/11/15 16:52    江苏鲜花全国速递   苏州最好的鲜花速递_{高端花艺领导品牌,中国最佳品牌花店}_江苏...
# 4     2019/11/15 16:52    江苏鲜花全国速递           网上送花,鲜花速递,全国领先的鲜花订购平台|时尚鲜花网
# ...                ...         ...                                   ...
# 5320  2019/11/16 11:37  江苏姑苏区鲜花礼品网   苏州鲜花店_江苏花店免费送花_江苏花店免费配送_江苏鲜花店_江苏...
# 5321  2019/11/16 11:37  江苏姑苏区鲜花礼品网          吴中鲜花店 - 江苏省苏州市吴中区鲜花店 - 时尚鲜花网
# 5322  2019/11/16 11:37  江苏姑苏区鲜花礼品网           苏州鲜花速递、苏州网上订花、苏州鲜花店 - 苏州鲜花网
# 5323  2019/11/16 11:37  江苏姑苏区鲜花礼品网                                   NaN
# 5324  2019/11/16 11:37  江苏姑苏区鲜花礼品网  姑苏区鲜花礼品网\n__【花您鲜花】在线预定\n鲜花\n_1h快速送达
#
#                   标题飘红                                               创意描述  \
# ...

# %%
data['搜索词'].unique().shape
# Out:
# (351,)

# %%
data.to_csv('merge.csv',index=False,encoding='gbk')
