# %%
import pandas as pd
data=pd.read_csv('test.csv')

# %%
data
# Out:
#      Unnamed: 0        time                                         host  \
# 0             0         b''                                          b''
# 1             1  b'2019-11'                            b'www.chanel.com'
# 2             2         b''                                          b''
# 3             3         b''                                          b''
# 4             4         b''                                          b''
# ..          ...         ...                                          ...
# 280         280         b''                  b'\xd0\xa1\xba\xec\xca\xe9'
# 281         281         b''          b'\xcd\xf8\xd2\xd7\xd0\xc2\xce\xc5'
# 282         282         b''  b'\xb3\xb1\xc5\xae\xb0\xd9\xb4\xee\xbf\xd8'
# 283         283         b''          b'\xb0\xd9\xb6\xc8\xbe\xad\xd1\xe9'
# 284         284         b''                                          b''
#
#                                                  title  \
# ...

# %%
data.to_csv('test.csv',encoding='gbk')

# %%
key_list=['时尚穿搭','穿搭','职场穿搭','服装买手店','女生穿搭','韩版穿搭','日系穿搭','运动穿搭','时尚资讯','个性穿搭','女大学生穿搭','白领穿搭']

# %%
key=[]
host=[]
red_title=[]
title=[]
content=[]
red_content=[]

# %%
def add(a,b,c,d,e,f):
    key.append(a)
    host.append(b)
    red_title.append(c)
    title.append(d)
    content.append(e)
    red_content.append(f)

# %%
#穿搭关键词无
#职场穿搭关键词无
#女生穿搭无
#日系穿搭无
#运动穿搭无
#个性穿搭无
#女大学生穿搭无
a='时尚资讯'
b='www.pop-fashion.com'
c='时尚 资讯'
d='时装资讯网站-POP全球时尚聚合平台_实时更新时尚数据'
e='时装资讯网站,1469余万图库,解读全球时尚潮流变化,分析国内外时尚产业趋势走向!专业服饰趋势平台,实时跟踪国际时尚潮..'
f='时尚 咨询 '
add(a,b,c,d,e,f)

# %%
key
# Out:
# ['时尚穿搭', '时尚穿搭', '时尚穿搭', '服装买手店', '服装买手店', '服装买手店', '服装买手店']

# %%
title
# Out:
# ['香奈儿2019/20秋冬高级成衣系列',
#  '潮流尖货_解锁时尚_吸睛穿搭尽在【京东】',
#  '气质时尚潮流女装搭配衣橱好搭款_甄选面料_魅力十足_上淘宝选购',
#  '服装买手店_48小时出品_先销售后订货',
#  '【58同城】服装店买手-上【58同城】轻松找工作',
#  '服装_ 找服装买手店_上阿里巴巴_海量爆品等你抢批',
#  '牛顿商学院Fashion MBA时装买手_开创买手制新商业模式',
#  '网购361度服装专卖店上京东_超值特卖_限时打折',
#  '淘宝服饰店_淘宝网2019新品_限时特卖_低至3折',
#  '唯品会_品牌特卖_天天有3折',
#  '韩版内搭_尖货新品低价购_淘宝网韩版内搭_今日必抢',
#  '气质韩版风衣怎么搭配衣橱好搭款_甄选面料_魅力十足_上淘宝选购',
#  'CHANEL News 香奈儿时尚资讯',
#  'WGSN 全面直击环球时尚热点 深度研究时尚咨询',
#  '时装资讯网站-POP全球时尚聚合平台_实时更新时尚数据']

# %%
result=pd.DataFrame()

# %%
result['key']=key
result['host']=host
result['red_title']=red_title
result['title']=title
result['content']=content
result['red_content']=red_content

# %%
result
# Out:
#       key                 host red_title                            title  \
# 0    时尚穿搭       www.chanel.com                         香奈儿2019/20秋冬高级成衣系列
# 1    时尚穿搭           www.jd.com     时尚 穿搭             潮流尖货_解锁时尚_吸睛穿搭尽在【京东】
# 2    时尚穿搭       www.taobao.com     时尚 搭配  气质时尚潮流女装搭配衣橱好搭款_甄选面料_魅力十足_上淘宝选购
# 3   服装买手店        www.jusut.com     服装买手店              服装买手店_48小时出品_先销售后订货
# 4   服装买手店           www.58.com      服装买手         【58同城】服装店买手-上【58同城】轻松找工作
# 5   服装买手店         www.1688.com     服装买手店        服装_ 找服装买手店_上阿里巴巴_海量爆品等你抢批
# 6   服装买手店      www.nbs-edu.com      时装买手  牛顿商学院Fashion MBA时装买手_开创买手制新商业模式
# 7   服装买手店           www.jd.com        服装         网购361度服装专卖店上京东_超值特卖_限时打折
# 8   服装买手店       www.taobao.com        服饰        淘宝服饰店_淘宝网2019新品_限时特卖_低至3折
# 9   服装买手店          www.vip.com                             唯品会_品牌特卖_天天有3折
# 10   韩版穿搭       www.taobao.com        韩版        韩版内搭_尖货新品低价购_淘宝网韩版内搭_今日必抢
# 11   韩版穿搭       www.taobao.com     韩版 搭配  气质韩版风衣怎么搭配衣橱好搭款_甄选面料_魅力十足_上淘宝选购
# ...

# %%
result.to_csv('result.csv',index=False,encoding='gbk')

# %%
import requests
url='https://www.baidu.com/s?ie=utf-8&f=3&rsv_bp=1&rsv_idx=1&tn=baidu&wd=%E7%A9%BF%E6%90%AD'
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 Safari/537.3'}
r=requests.get(url,headers=headers)

# %%
r.content.decode('utf-8')
# Out:
# '<!DOCTYPE html>\n<!--STATUS OK-->\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\t\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\n\n\n<html>\n\t<head>\n\t\t\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\t\t<meta http-equiv="content-type" content="text/html;charset=utf-8">\n\t\t<meta content="always" name="referrer">\n        <meta name="theme-color" content="#2932e1">\n        <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />\n        <link rel="icon" sizes="any" mask href="//www.baidu.com/img/baidu_85beaf5496f291521eb75ba38eacbd87.svg">\n        <link rel="search" type="application/opensearchdescription+xml" href="/content-search.xml" title="百度搜索" />\n\t\t\n\t\t\n<title>穿搭_百度搜索</title>\n\n\t\t\n\n\t\t\n<style data-for="result" type="text/css" id="css_newi_re
# ...
